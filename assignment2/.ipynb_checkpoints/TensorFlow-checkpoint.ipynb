# %% [markdown]
# ## What's this TensorFlow business?
#
# You've written a lot of code in this assignment to provide a whole host of neural network functionality. Dropout, Batch Norm, and 2D convolutions are some of the workhorses of deep learning in computer vision. You've also worked hard to make your code efficient and vectorized.
#
# For the last part of this assignment, though, we're going to leave behind your beautiful codebase and instead migrate to one of two popular deep learning frameworks: in this instance, TensorFlow (or PyTorch, if you switch over to that notebook)
#
# #### What is it?
# TensorFlow is a system for executing computational graphs over Tensor objects, with native support for performing backpropogation for its Variables. In it, we work with Tensors which are n-dimensional arrays analogous to the numpy ndarray.
#
# #### Why?
#
# * Our code will now run on GPUs! Much faster training. Writing your own modules to run on GPUs is beyond the scope of this class, unfortunately.
# * We want you to be ready to use one of these frameworks for your project so you can experiment more efficiently than if you were writing every feature you want to use by hand.
# * We want you to stand on the shoulders of giants! TensorFlow and PyTorch are both excellent frameworks that will make your lives a lot easier, and now that you understand their guts, you are free to use them :)
# * We want you to be exposed to the sort of deep learning code you might run into in academia or industry.

# %% [markdown]
# ## How will I learn TensorFlow?
#
# TensorFlow has many excellent tutorials available, including those from [Google themselves](https://www.tensorflow.org/get_started/get_started).
#
# Otherwise, this notebook will walk you through much of what you need to do to train models in TensorFlow. See the end of the notebook for some links to helpful tutorials if you want to learn more or need further clarification on topics that aren't fully explained here.

# %% [markdown]
# ## Load Datasets

# %%
import tensorflow as tf
import numpy as np
import math
import timeit
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=10000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)

    # Subsample the data
    mask = range(num_training, num_training + num_validation)
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = range(num_training)
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = range(num_test)
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 32, 32, 3)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 32, 32, 3)
# Validation labels shape:  (1000,)
# Test data shape:  (10000, 32, 32, 3)
# Test labels shape:  (10000,)

# %% [markdown]
# ## Example Model
#
# ### Some useful utilities
#
# . Remember that our image data is initially N x H x W x C, where:
# * N is the number of datapoints
# * H is the height of each image in pixels
# * W is the height of each image in pixels
# * C is the number of channels (usually 3: R, G, B)
#
# This is the right way to represent the data when we are doing something like a 2D convolution, which needs spatial understanding of where the pixels are relative to each other. When we input image data into fully connected affine layers, however, we want each data example to be represented by a single vector -- it's no longer useful to segregate the different channels, rows, and columns of the data.

# %% [markdown]
# ### The example model itself
#
# The first step to training your own model is defining its architecture.
#
# Here's an example of a convolutional neural network defined in TensorFlow -- try to understand what each line is doing, remembering that each layer is composed upon the previous layer. We haven't trained anything yet - that'll come next - for now, we want you to understand how everything gets set up.
#
# In that example, you see 2D convolutional layers (Conv2d), ReLU activations, and fully-connected layers (Linear). You also see the Hinge loss function, and the Adam optimizer being used.
#
# Make sure you understand why the parameters of the Linear layer are 5408 and 10.
#
# ### TensorFlow Details
# In TensorFlow, much like in our previous notebooks, we'll first specifically initialize our variables, and then our network model.

# %%
# clear old variables
tf.reset_default_graph()

# setup input (e.g. the data that changes every batch)
# The first dim is None, and gets sets automatically based on batch size fed in
X = tf.placeholder(tf.float32, [None, 32, 32, 3])
y = tf.placeholder(tf.int64, [None])
is_training = tf.placeholder(tf.bool)

def simple_model(X,y):
    # define our weights (e.g. init_two_layer_convnet)
    
    # setup variables
    Wconv1 = tf.get_variable("Wconv1", shape=[7, 7, 3, 32])
    bconv1 = tf.get_variable("bconv1", shape=[32])
    W1 = tf.get_variable("W1", shape=[5408, 10])
    b1 = tf.get_variable("b1", shape=[10])

    # define our graph (e.g. two_layer_convnet)
    a1 = tf.nn.conv2d(X, Wconv1, strides=[1,2,2,1], padding='VALID') + bconv1
    h1 = tf.nn.relu(a1)
    h1_flat = tf.reshape(h1,[-1,5408])
    print(h1_flat.get_shape(), W1.get_shape())
    y_out = tf.matmul(h1_flat,W1) + b1
    return y_out

y_out = simple_model(X,y)

# define our loss
total_loss = tf.losses.hinge_loss(tf.one_hot(y,10),logits=y_out)
mean_loss = tf.reduce_mean(total_loss)

# define our optimizer
optimizer = tf.train.AdamOptimizer(5e-4) # select optimizer and set learning rate
train_step = optimizer.minimize(mean_loss)
# Out:
# (?, 5408) (5408, 10)

# %% [markdown]
# TensorFlow supports many other layer types, loss functions, and optimizers - you will experiment with these next. Here's the official API documentation for these (if any of the parameters used above were unclear, this resource will also be helpful).
#
# * Layers, Activations, Loss functions : https://www.tensorflow.org/api_guides/python/nn
# * Optimizers: https://www.tensorflow.org/api_guides/python/train#Optimizers
# * BatchNorm: https://www.tensorflow.org/api_docs/python/tf/layers/batch_normalization

# %% [markdown]
# ### Training the model on one epoch
# While we have defined a graph of operations above, in order to execute TensorFlow Graphs, by feeding them input data and computing the results, we first need to create a `tf.Session` object. A session encapsulates the control and state of the TensorFlow runtime. For more information, see the TensorFlow [Getting started](https://www.tensorflow.org/get_started/get_started) guide.
#
# Optionally we can also specify a device context such as `/cpu:0` or `/gpu:0`. For documentation on this behavior see [this TensorFlow guide](https://www.tensorflow.org/tutorials/using_gpu)
#
# You should see a validation loss of around 0.4 to 0.6 and an accuracy of 0.30 to 0.35 below

# %%
def run_model(session, predict, loss_val, Xd, yd,
              epochs=1, batch_size=64, print_every=100,
              training=None, plot_losses=False):
    # have tensorflow compute accuracy
    correct_prediction = tf.equal(tf.argmax(predict,1), y)
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    
    # shuffle indicies
    train_indicies = np.arange(Xd.shape[0])
    np.random.shuffle(train_indicies)

    training_now = training is not None
    
    # setting up variables we want to compute (and optimizing)
    # if we have a training function, add that to things we compute
    variables = [mean_loss,correct_prediction,accuracy]
    if training_now:
        variables[-1] = training
    
    # counter 
    iter_cnt = 0
    for e in range(epochs):
        # keep track of losses and accuracy
        correct = 0
        losses = []
        # make sure we iterate over the dataset once
        for i in range(int(math.ceil(Xd.shape[0]/batch_size))):
            # generate indicies for the batch
            start_idx = (i*batch_size)%Xd.shape[0]
            idx = train_indicies[start_idx:start_idx+batch_size]
            
            # create a feed dictionary for this batch
            feed_dict = {X: Xd[idx,:],
                         y: yd[idx],
                         is_training: training_now }
            # get batch size
            actual_batch_size = yd[idx].shape[0]
            
            # have tensorflow compute loss and correct predictions
            # and (if given) perform a training step
            loss, corr, _ = session.run(variables,feed_dict=feed_dict)
            
            # aggregate performance stats
            losses.append(loss*actual_batch_size)
            correct += np.sum(corr)
            
            # print every now and then
            if training_now and (iter_cnt % print_every) == 0:
                print("Iteration {0}: with minibatch training loss = {1:.3g} and accuracy of {2:.2g}"\
                      .format(iter_cnt,loss,np.sum(corr)/actual_batch_size))
            iter_cnt += 1
        total_correct = correct/Xd.shape[0]
        total_loss = np.sum(losses)/Xd.shape[0]
        print("Epoch {2}, Overall loss = {0:.3g} and accuracy of {1:.3g}"\
              .format(total_loss,total_correct,e+1))
        if plot_losses:
            plt.plot(losses)
            plt.grid(True)
            plt.title('Epoch {} Loss'.format(e+1))
            plt.xlabel('minibatch number')
            plt.ylabel('minibatch loss')
            plt.show()
    return total_loss,total_correct

with tf.Session() as sess:
    with tf.device("/gpu:0"): #"/cpu:0" or "/gpu:0" 
        sess.run(tf.global_variables_initializer())
        print('Training')
        run_model(sess,y_out,mean_loss,X_train,y_train,1,64,100,train_step,True)
        print('Validation')
        run_model(sess,y_out,mean_loss,X_val,y_val,1,64)
# Out:
# Training
# Iteration 0: with minibatch training loss = 10.6 and accuracy of 0.12
# Iteration 100: with minibatch training loss = 1.13 and accuracy of 0.16
# Iteration 200: with minibatch training loss = 0.837 and accuracy of 0.31
# Iteration 300: with minibatch training loss = 0.537 and accuracy of 0.3
# Iteration 400: with minibatch training loss = 0.658 and accuracy of 0.34
# Iteration 500: with minibatch training loss = 0.592 and accuracy of 0.28
# Iteration 600: with minibatch training loss = 0.533 and accuracy of 0.31
# Iteration 700: with minibatch training loss = 0.495 and accuracy of 0.33
# Epoch 1, Overall loss = 0.777 and accuracy of 0.302
# Validation
# Epoch 1, Overall loss = 0.462 and accuracy of 0.357

# %% [markdown]
# ## Training a specific model
#
# In this section, we're going to specify a model for you to construct. The goal here isn't to get good performance (that'll be next), but instead to get comfortable with understanding the TensorFlow documentation and configuring your own model.
#
# Using the code provided above as guidance, and using the following TensorFlow documentation, specify a model with the following architecture:
#
# * 7x7 Convolutional Layer with 32 filters and stride of 1
# * ReLU Activation Layer
# * Spatial Batch Normalization Layer (trainable parameters, with scale and centering)
# * 2x2 Max Pooling layer with a stride of 2
# * Affine layer with 1024 output units
# * ReLU Activation Layer
# * Affine layer from 1024 input units to 10 outputs

# %%
# clear old variables
tf.reset_default_graph()
# def simple_model(X,y):
#     # define our weights (e.g. init_two_layer_convnet)
    
#     # setup variables
#     Wconv1 = tf.get_variable("Wconv1", shape=[7, 7, 3, 32])
#     bconv1 = tf.get_variable("bconv1", shape=[32])
#     W1 = tf.get_variable("W1", shape=[5408, 10])
#     b1 = tf.get_variable("b1", shape=[10])

#     # define our graph (e.g. two_layer_convnet)
#     a1 = tf.nn.conv2d(X, Wconv1, strides=[1,2,2,1], padding='VALID') + bconv1
#     h1 = tf.nn.relu(a1)
#     h1_flat = tf.reshape(h1,[-1,5408])
#     y_out = tf.matmul(h1_flat,W1) + b1
#     return y_out
# define our input (e.g. the data that changes every batch)
# The first dim is None, and gets sets automatically based on batch size fed in
X = tf.placeholder(tf.float32, [None, 32, 32, 3])
y = tf.placeholder(tf.int64, [None])
is_training = tf.placeholder(tf.bool)

# define model
def complex_model(X,y,is_training):
    Wconv1 = tf.get_variable("Wconv1", shape=[7,7,3,32])
    bconv1 = tf.get_variable("bconv1", shape=[32])
    gamma = tf.get_variable("gamma", shape=[32])
    beta = tf.get_variable("beta", shape=[32])
    W1 = tf.get_variable("W1", shape=[5408,1024])
    b1 = tf.get_variable("b1", shape=[1024])
    W2 = tf.get_variable("W2", shape=[1024,10])
    b2 = tf.get_variable("b2", shape=[10])
    eps = tf.constant(10e-5)
    
    a1 = tf.nn.conv2d(X, Wconv1, strides = [1, 1, 1, 1], padding='VALID') + bconv1
    c1 = tf.nn.relu(a1)
    mu, var = tf.nn.moments(c1,axes=[0, 1, 2])
    d1 = tf.nn.batch_normalization(c1, mean=mu, variance=var, scale=gamma, offset=beta, variance_epsilon=eps)
    h1 = tf.nn.max_pool(d1,ksize=[1,2,2,1],strides=[1,2,2,1],padding='VALID',data_format='NHWC')
    h1_flat = tf.reshape(h1,[-1,5408])
    print(h1_flat.get_shape(), W1.get_shape())
    h2 = tf.matmul(h1_flat, W1) + b1
    h2 = tf.nn.relu(h2)
    y_out = tf.matmul(h2, W2) + b2
    return y_out

y_out = complex_model(X,y,is_training)
# Out:
# (?, 5408) (5408, 1024)

# %% [markdown]
# To make sure you're doing the right thing, use the following tool to check the dimensionality of your output (it should be 64 x 10, since our batches have size 64 and the output of the final affine layer should be 10, corresponding to our 10 classes):

# %%
# Now we're going to feed a random batch into the model 
# and make sure the output is the right size
x = np.random.randn(64, 32, 32,3)
with tf.Session() as sess:
    with tf.device("/cpu:0"): #"/cpu:0" or "/gpu:0"
        tf.global_variables_initializer().run()

        ans = sess.run(y_out,feed_dict={X:x,is_training:True})
        # %timeit sess.run(y_out,feed_dict={X:x,is_training:True})
        print(ans.shape)
        print(np.array_equal(ans.shape, np.array([64, 10])))
# Out:
# 4.6 ms ± 14.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# (64, 10)
# True

# %%
from tensorflow.python.client import device_lib

device_lib.list_local_devices()
# Out:
# [name: "/cpu:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 16097638489603901717, name: "/gpu:0"
#  device_type: "GPU"
#  memory_limit: 176088678
#  locality {
#    bus_id: 1
#  }
#  incarnation: 11323572067909761112
#  physical_device_desc: "device: 0, name: GeForce GTX 960M, pci bus id: 0000:02:00.0"]

# %% [markdown]
# You should see the following from the run above
#
# `(64, 10)`
#
# `True`

# %% [markdown]
# ### GPU!
#
# Now, we're going to try and start the model under the GPU device, the rest of the code stays unchanged and all our variables and operations will be computed using accelerated code paths. However, if there is no GPU, we get a Python exception and have to rebuild our graph. On a dual-core CPU, you might see around 50-80ms/batch running the above, while the Google Cloud GPUs (run below) should be around 2-5ms/batch.

# %%
try:
    with tf.Session() as sess:
        with tf.device("/gpu:0") as dev: #"/cpu:0" or "/gpu:0"
            tf.global_variables_initializer().run()

            ans = sess.run(y_out,feed_dict={X:x,is_training:True})
            # %timeit sess.run(y_out,feed_dict={X:x,is_training:True})
except tf.errors.InvalidArgumentError:
    print("no gpu found, please use Google Cloud if you want GPU acceleration")    
    # rebuild the graph
    # trying to start a GPU throws an exception 
    # and also trashes the original graph
    tf.reset_default_graph()
    X = tf.placeholder(tf.float32, [None, 32, 32, 3])
    y = tf.placeholder(tf.int64, [None])
    is_training = tf.placeholder(tf.bool)
    y_out = complex_model(X,y,is_training)
# Out:
# 4.68 ms ± 166 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# You should observe that even a simple forward pass like this is significantly faster on the GPU. So for the rest of the assignment (and when you go train your models in assignment 3 and your project!), you should use GPU devices. However, with TensorFlow, the default device is a GPU if one is available, and a CPU otherwise, so we can skip the device specification from now on.

# %% [markdown]
# ### Train the model.
#
# Now that you've seen how to define a model and do a single forward pass of some data through it, let's  walk through how you'd actually train one whole epoch over your training data (using the complex_model you created provided above).
#
# Make sure you understand how each TensorFlow function used below corresponds to what you implemented in your custom neural network implementation.
#
# First, set up an **RMSprop optimizer** (using a 1e-3 learning rate) and a **cross-entropy loss** function. See the TensorFlow documentation for more information
# * Layers, Activations, Loss functions : https://www.tensorflow.org/api_guides/python/nn
# * Optimizers: https://www.tensorflow.org/api_guides/python/train#Optimizers

# %%
# Inputs
#     y_out: is what your model computes
#     y: is your TensorFlow variable with label information
# Outputs
#    mean_loss: a TensorFlow variable (scalar) with numerical loss
#    optimizer: a TensorFlow optimizer
# This should be ~3 lines of code!
# # define our loss
# total_loss = tf.losses.hinge_loss(tf.one_hot(y,10),logits=y_out)
# mean_loss = tf.reduce_mean(total_loss)

# # define our optimizer
# optimizer = tf.train.AdamOptimizer(5e-4) # select optimizer and set learning rate
# train_step = optimizer.minimize(mean_loss)

mean_loss = None
optimizer = None
total_loss = tf.losses.softmax_cross_entropy(tf.one_hot(y,10), logits=y_out)
mean_loss = tf.reduce_mean(total_loss)
optimizer = tf.train.RMSPropOptimizer(1e-3)

# %%
# batch normalization in tensorflow requires this extra dependency
extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
with tf.control_dependencies(extra_update_ops):
    train_step = optimizer.minimize(mean_loss)

# %% [markdown]
# ### Train the model
# Below we'll create a session and train the model over one epoch. You should see a loss of 1.4 to 2.0 and an accuracy of 0.4 to 0.5. There will be some variation due to random seeds and differences in initialization

# %%
sess = tf.Session()

sess.run(tf.global_variables_initializer())
print('Training')
run_model(sess,y_out,mean_loss,X_train,y_train,1,64,100,train_step)
# Out:
# Training
# Iteration 0: with minibatch training loss = 2.43 and accuracy of 0.078
# Iteration 100: with minibatch training loss = 2.21 and accuracy of 0.28
# Iteration 200: with minibatch training loss = 1.42 and accuracy of 0.48
# Iteration 300: with minibatch training loss = 1.26 and accuracy of 0.53
# Iteration 400: with minibatch training loss = 1.22 and accuracy of 0.55
# Iteration 500: with minibatch training loss = 1.32 and accuracy of 0.53
# Iteration 600: with minibatch training loss = 1.58 and accuracy of 0.52
# Iteration 700: with minibatch training loss = 1.18 and accuracy of 0.55
# Epoch 1, Overall loss = 1.5 and accuracy of 0.461
# (1.4993285248230914, 0.4613469387755102)

# %% [markdown]
# ### Check the accuracy of the model.
#
# Let's see the train and test code in action -- feel free to use these methods when evaluating the models you develop below. You should see a loss of 1.3 to 2.0 with an accuracy of 0.45 to 0.55.

# %%
print('Validation')
run_model(sess,y_out,mean_loss,X_val,y_val,1,64)
# Out:
# Validation
# Epoch 1, Overall loss = 1.15 and accuracy of 0.588
# (1.153221978187561, 0.58799999999999997)

# %% [markdown]
# ## Train a _great_ model on CIFAR-10!
#
# Now it's your job to experiment with architectures, hyperparameters, loss functions, and optimizers to train a model that achieves ** >= 70% accuracy on the validation set** of CIFAR-10. You can use the `run_model` function from above.

# %% [markdown]
# ### Things you should try:
# - **Filter size**: Above we used 7x7; this makes pretty pictures but smaller filters may be more efficient
# - **Number of filters**: Above we used 32 filters. Do more or fewer do better?
# - **Pooling vs Strided Convolution**: Do you use max pooling or just stride convolutions?
# - **Batch normalization**: Try adding spatial batch normalization after convolution layers and vanilla batch normalization after affine layers. Do your networks train faster?
# - **Network architecture**: The network above has two layers of trainable parameters. Can you do better with a deep network? Good architectures to try include:
#     - [conv-relu-pool]xN -> [affine]xM -> [softmax or SVM]
#     - [conv-relu-conv-relu-pool]xN -> [affine]xM -> [softmax or SVM]
#     - [batchnorm-relu-conv]xN -> [affine]xM -> [softmax or SVM]
# - **Use TensorFlow Scope**: Use TensorFlow scope and/or [tf.layers](https://www.tensorflow.org/api_docs/python/tf/layers) to make it easier to write deeper networks. See [this tutorial](https://www.tensorflow.org/tutorials/layers) for how to use `tf.layers`.
# - **Use Learning Rate Decay**: [As the notes point out](http://cs231n.github.io/neural-networks-3/#anneal), decaying the learning rate might help the model converge. Feel free to decay every epoch, when loss doesn't change over an entire epoch, or any other heuristic you find appropriate. See the [Tensorflow documentation](https://www.tensorflow.org/versions/master/api_guides/python/train#Decaying_the_learning_rate) for learning rate decay.
# - **Global Average Pooling**: Instead of flattening and then having multiple affine layers, perform convolutions until your image gets small (7x7 or so) and then perform an average pooling operation to get to a 1x1 image picture (1, 1 , Filter#), which is then reshaped into a (Filter#) vector. This is used in [Google's Inception Network](https://arxiv.org/abs/1512.00567) (See Table 1 for their architecture).
# - **Regularization**: Add l2 weight regularization, or perhaps use [Dropout as in the TensorFlow MNIST tutorial](https://www.tensorflow.org/get_started/mnist/pros)
#
# ### Tips for training
# For each network architecture that you try, you should tune the learning rate and regularization strength. When doing this there are a couple important things to keep in mind:
#
# - If the parameters are working well, you should see improvement within a few hundred iterations
# - Remember the coarse-to-fine approach for hyperparameter tuning: start by testing a large range of hyperparameters for just a few training iterations to find the combinations of parameters that are working at all.
# - Once you have found some sets of parameters that seem to work, search more finely around these parameters. You may need to train for more epochs.
# - You should use the validation set for hyperparameter search, and we'll save the test set for evaluating your architecture on the best parameters as selected by the validation set.
#
# ### Going above and beyond
# If you are feeling adventurous there are many other features you can implement to try and improve your performance. You are **not required** to implement any of these; however they would be good things to try for extra credit.
#
# - Alternative update steps: For the assignment we implemented SGD+momentum, RMSprop, and Adam; you could try alternatives like AdaGrad or AdaDelta.
# - Alternative activation functions such as leaky ReLU, parametric ReLU, ELU, or MaxOut.
# - Model ensembles
# - Data augmentation
# - New Architectures
#   - [ResNets](https://arxiv.org/abs/1512.03385) where the input from the previous layer is added to the output.
#   - [DenseNets](https://arxiv.org/abs/1608.06993) where inputs into previous layers are concatenated together.
#   - [This blog has an in-depth overview](https://chatbotslife.com/resnets-highwaynets-and-densenets-oh-my-9bb15918ee32)
#
# If you do decide to implement something extra, clearly describe it in the "Extra Credit Description" cell below.
#
# ### What we expect
# At the very least, you should be able to train a ConvNet that gets at **>= 70% accuracy on the validation set**. This is just a lower bound - if you are careful it should be possible to get accuracies much higher than that! Extra credit points will be awarded for particularly high-scoring models or unique approaches.
#
# You should use the space below to experiment and train your network. The final cell in this notebook should contain the training and validation set accuracies for your final trained network.
#
# Have fun and happy training!

# %%
# Feel free to play with this cell
def my_model(X,y,is_training, reg_str=3e-3):
    Wcon1 = tf.get_variable("Wcon1",shape=[3,3,3,10])
    bcon1 = tf.get_variable("bcon1",shape=[10])
    Wcon2 = tf.get_variable("Wcon2",shape=[3,3,10,32])
    bcon2 = tf.get_variable("bcon2",shape=[32])
    Wcon3 = tf.get_variable("Wcon3",shape=[3,3,32,64])
    bcon3 = tf.get_variable("bcon3",shape=[64])
    Wcon4 = tf.get_variable("Wcon4",shape=[3,3,64,128])
    bcon4 = tf.get_variable("bcon4",shape=[128])
    W1 = tf.get_variable("W1",shape=[8192,1024])
    b1 = tf.get_variable("b1",shape=[1024])
    W2 = tf.get_variable("W2", shape=[1024,10])
    b2 = tf.get_variable("b2", shape=[10])
    gamma1 = tf.get_variable("gamma1", shape=[32])
    beta1 = tf.get_variable("beta1", shape=[32])
    gamma2 = tf.get_variable("gamma2", shape=[128])
    beta2 = tf.get_variable("beta2", shape=[128])
    gamma3 = tf.get_variable("gamma3", shape=[1024])
    beta3 = tf.get_variable("beta3", shape=[1024])
    eps = tf.constant(10e-5)
    c1 = tf.nn.conv2d(X, Wcon1, strides=[1,1,1,1], padding='SAME')  + bcon1
    r1 = tf.nn.relu(c1)
    c2 = tf.nn.conv2d(r1, Wcon2, strides=[1,1,1,1], padding='SAME')  + bcon2
    mu, var = tf.nn.moments(c2,axes=[0, 1, 2])
    ba1 = tf.nn.batch_normalization(c2, mean=mu,variance=var,scale=gamma1, offset=beta1,variance_epsilon=eps)
    p1 = tf.nn.max_pool(ba1, ksize=[1,2,2,1], strides=[1,2,2,1],padding='VALID',data_format='NHWC')
    c3 = tf.nn.conv2d(p1, Wcon3, strides=[1,1,1,1], padding='SAME')  + bcon3
    r2 = tf.nn.relu(c3)
    c4 = tf.nn.conv2d(r2, Wcon4, strides=[1,1,1,1], padding='SAME')  + bcon4
    mu, var = tf.nn.moments(c4,axes=[0, 1, 2])
    ba2 = tf.nn.batch_normalization(c4, mean=mu,variance=var,scale=gamma2, offset=beta2,variance_epsilon=eps)
    p2 = tf.nn.max_pool(ba2, ksize=[1,2,2,1], strides=[1,2,2,1],padding='VALID',data_format='NHWC')
    h1 = tf.reshape(p2,[-1,8192])
    h2 = tf.matmul(h1,W1) + b1
    mu, var = tf.nn.moments(h2,axes=[0])
    ba3 = tf.nn.batch_normalization(h2, mean=mu,variance=var,scale=gamma3, offset=beta3, variance_epsilon=eps)
    r3 = tf.nn.relu(ba3)
    if is_training is True:
        keep_prob = 0.6
    else:
        keep_prob = 1
    dr1 = tf.nn.dropout(r3, keep_prob=keep_prob)
    y_out = tf.matmul(dr1, W2) + b2
    reg = 0.5 * reg_str * (tf.reduce_sum(tf.square(W1))+tf.reduce_sum(tf.square(W2)))
    return {'y_out':y_out, 'reg':reg}
    
tf.reset_default_graph()

X = tf.placeholder(tf.float32, [None, 32, 32, 3])
y = tf.placeholder(tf.int64, [None])
is_training = tf.placeholder(tf.bool)

y_out = my_model(X,y,is_training)
mean_loss = tf.reduce_mean(tf.losses.softmax_cross_entropy(tf.one_hot(y,10), logits=y_out['y_out']) + y_out['reg'])
optimizer = tf.train.RMSPropOptimizer(1e-3)

# batch normalization in tensorflow requires this extra dependency
extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
with tf.control_dependencies(extra_update_ops):
    train_step = optimizer.minimize(mean_loss)

# %%
# Feel free to play with this cell
# This default code creates a session
# and trains your model for 10 epochs
# then prints the validation set accuracy
sess = tf.Session()

sess.run(tf.global_variables_initializer())
print('Training')
run_model(sess,y_out['y_out'],mean_loss,X_train,y_train,100,64,100,train_step,True)
print('Validation')
run_model(sess,y_out['y_out'],mean_loss,X_val,y_val,1,64)
# Out:
# Training
# Iteration 0: with minibatch training loss = 5.07 and accuracy of 0.094
# Iteration 100: with minibatch training loss = 4.94 and accuracy of 0.17
# Iteration 200: with minibatch training loss = 2.11 and accuracy of 0.38
# Iteration 300: with minibatch training loss = 1.63 and accuracy of 0.47
# Iteration 400: with minibatch training loss = 1.59 and accuracy of 0.45
# Iteration 500: with minibatch training loss = 1.51 and accuracy of 0.53
# Iteration 600: with minibatch training loss = 1.53 and accuracy of 0.59
# Iteration 700: with minibatch training loss = 1.52 and accuracy of 0.61
# Epoch 1, Overall loss = 2.22 and accuracy of 0.47
# Iteration 800: with minibatch training loss = 1.14 and accuracy of 0.72
# Iteration 900: with minibatch training loss = 1.3 and accuracy of 0.64
# Iteration 1000: with minibatch training loss = 1.21 and accuracy of 0.62
# Iteration 1100: with minibatch training loss = 1.2 and accuracy of 0.73
# Iteration 1200: with minibatch training loss = 1.1 and accuracy of 0.61
# Iteration 1300: with minibatch training loss = 1.22 and accuracy of 0.69
# Iteration 1400: with minibatch training loss = 0.896 and accuracy of 0.72
# Iteration 1500: with minibatch training loss = 0.919 and accuracy of 0.78
# Epoch 2, Overall loss = 1.2 and accuracy of 0.649
# Iteration 1600: with minibatch training loss = 1.06 and accuracy of 0.72
# Iteration 1700: with minibatch training loss = 0.996 and accuracy of 0.7
# Iteration 1800: with minibatch training loss = 0.976 and accuracy of 0.77
# Iteration 1900: with minibatch training loss = 1.18 and accuracy of 0.59
# Iteration 2000: with minibatch training loss = 0.966 and accuracy of 0.7
# Iteration 2100: with minibatch training loss = 1.07 and accuracy of 0.66
# Iteration 2200: with minibatch training loss = 0.957 and accuracy of 0.73
# Epoch 3, Overall loss = 1.07 and accuracy of 0.695
# Iteration 2300: with minibatch training loss = 1.17 and accuracy of 0.64
# Iteration 2400: with minibatch training loss = 0.893 and accuracy of 0.77
# Iteration 2500: with minibatch training loss = 0.946 and accuracy of 0.72
# Iteration 2600: with minibatch training loss = 0.948 and accuracy of 0.73
# Iteration 2700: with minibatch training loss = 0.798 and accuracy of 0.77
# Iteration 2800: with minibatch training loss = 1.35 and accuracy of 0.56
# Iteration 2900: with minibatch training loss = 0.872 and accuracy of 0.81
# Iteration 3000: with minibatch training loss = 1.15 and accuracy of 0.62
# Epoch 4, Overall loss = 0.983 and accuracy of 0.726
# Iteration 3100: with minibatch training loss = 0.944 and accuracy of 0.77
# Iteration 3200: with minibatch training loss = 1.04 and accuracy of 0.66
# Iteration 3300: with minibatch training loss = 0.909 and accuracy of 0.78
# Iteration 3400: with minibatch training loss = 0.946 and accuracy of 0.72
# Iteration 3500: with minibatch training loss = 0.982 and accuracy of 0.75
# Iteration 3600: with minibatch training loss = 0.831 and accuracy of 0.78
# Iteration 3700: with minibatch training loss = 1.01 and accuracy of 0.78
# Iteration 3800: with minibatch training loss = 0.705 and accuracy of 0.86
# Epoch 5, Overall loss = 0.918 and accuracy of 0.751
# Iteration 3900: with minibatch training loss = 0.795 and accuracy of 0.81
# Iteration 4000: with minibatch training loss = 1.04 and accuracy of 0.81
# Iteration 4100: with minibatch training loss = 1.05 and accuracy of 0.78
# Iteration 4200: with minibatch training loss = 0.814 and accuracy of 0.81
# Iteration 4300: with minibatch training loss = 1.01 and accuracy of 0.8
# Iteration 4400: with minibatch training loss = 0.726 and accuracy of 0.84
# Iteration 4500: with minibatch training loss = 0.962 and accuracy of 0.83
# Epoch 6, Overall loss = 0.862 and accuracy of 0.774
# Iteration 4600: with minibatch training loss = 1.27 and accuracy of 0.66
# Iteration 4700: with minibatch training loss = 0.829 and accuracy of 0.8
# Iteration 4800: with minibatch training loss = 1.07 and accuracy of 0.73
# Iteration 4900: with minibatch training loss = 0.604 and accuracy of 0.84
# Iteration 5000: with minibatch training loss = 0.917 and accuracy of 0.73
# Iteration 5100: with minibatch training loss = 0.772 and accuracy of 0.83
# Iteration 5200: with minibatch training loss = 0.849 and accuracy of 0.81
# Iteration 5300: with minibatch training loss = 0.756 and accuracy of 0.81
# Epoch 7, Overall loss = 0.812 and accuracy of 0.795
# Iteration 5400: with minibatch training loss = 0.804 and accuracy of 0.75
# Iteration 5500: with minibatch training loss = 0.68 and accuracy of 0.83
# Iteration 5600: with minibatch training loss = 0.75 and accuracy of 0.77
# Iteration 5700: with minibatch training loss = 0.819 and accuracy of 0.83
# Iteration 5800: with minibatch training loss = 0.715 and accuracy of 0.8
# Iteration 5900: with minibatch training loss = 0.832 and accuracy of 0.83
# Iteration 6000: with minibatch training loss = 0.655 and accuracy of 0.81
# Iteration 6100: with minibatch training loss = 0.99 and accuracy of 0.8
# Epoch 8, Overall loss = 0.768 and accuracy of 0.816
# Iteration 6200: with minibatch training loss = 0.859 and accuracy of 0.8
# Iteration 6300: with minibatch training loss = 0.627 and accuracy of 0.88
# Iteration 6400: with minibatch training loss = 0.666 and accuracy of 0.84
# Iteration 6500: with minibatch training loss = 0.685 and accuracy of 0.88
# Iteration 6600: with minibatch training loss = 0.741 and accuracy of 0.83
# Iteration 6700: with minibatch training loss = 0.644 and accuracy of 0.86
# Iteration 6800: with minibatch training loss = 0.603 and accuracy of 0.91
# Epoch 9, Overall loss = 0.726 and accuracy of 0.835
# Iteration 6900: with minibatch training loss = 0.654 and accuracy of 0.86
# Iteration 7000: with minibatch training loss = 0.739 and accuracy of 0.83
# Iteration 7100: with minibatch training loss = 0.702 and accuracy of 0.83
# Iteration 7200: with minibatch training loss = 0.634 and accuracy of 0.89
# Iteration 7300: with minibatch training loss = 0.752 and accuracy of 0.83
# Iteration 7400: with minibatch training loss = 0.652 and accuracy of 0.86
# Iteration 7500: with minibatch training loss = 0.645 and accuracy of 0.89
# Iteration 7600: with minibatch training loss = 0.743 and accuracy of 0.77
# Epoch 10, Overall loss = 0.69 and accuracy of 0.852
# Iteration 7700: with minibatch training loss = 0.969 and accuracy of 0.73
# Iteration 7800: with minibatch training loss = 0.66 and accuracy of 0.86
# Iteration 7900: with minibatch training loss = 0.529 and accuracy of 0.94
# Iteration 8000: with minibatch training loss = 0.707 and accuracy of 0.88
# Iteration 8100: with minibatch training loss = 0.631 and accuracy of 0.86
# Iteration 8200: with minibatch training loss = 0.533 and accuracy of 0.92
# Iteration 8300: with minibatch training loss = 0.579 and accuracy of 0.91
# Iteration 8400: with minibatch training loss = 0.732 and accuracy of 0.83
# Epoch 11, Overall loss = 0.656 and accuracy of 0.867
# Iteration 8500: with minibatch training loss = 0.498 and accuracy of 0.91
# Iteration 8600: with minibatch training loss = 0.603 and accuracy of 0.92
# Iteration 8700: with minibatch training loss = 0.532 and accuracy of 0.95
# Iteration 8800: with minibatch training loss = 0.691 and accuracy of 0.89
# Iteration 8900: with minibatch training loss = 0.499 and accuracy of 0.92
# Iteration 9000: with minibatch training loss = 0.741 and accuracy of 0.81
# Iteration 9100: with minibatch training loss = 0.584 and accuracy of 0.91
# Epoch 12, Overall loss = 0.627 and accuracy of 0.882
# Iteration 9200: with minibatch training loss = 0.596 and accuracy of 0.89
# Iteration 9300: with minibatch training loss = 0.665 and accuracy of 0.88
# Iteration 9400: with minibatch training loss = 0.832 and accuracy of 0.81
# Iteration 9500: with minibatch training loss = 0.634 and accuracy of 0.92
# Iteration 9600: with minibatch training loss = 0.561 and accuracy of 0.92
# Iteration 9700: with minibatch training loss = 0.584 and accuracy of 0.88
# Iteration 9800: with minibatch training loss = 0.664 and accuracy of 0.86
# Iteration 9900: with minibatch training loss = 0.614 and accuracy of 0.89
# Epoch 13, Overall loss = 0.605 and accuracy of 0.89
# Iteration 10000: with minibatch training loss = 0.507 and accuracy of 0.91
# Iteration 10100: with minibatch training loss = 0.531 and accuracy of 0.94
# Iteration 10200: with minibatch training loss = 0.712 and accuracy of 0.86
# Iteration 10300: with minibatch training loss = 0.631 and accuracy of 0.91
# Iteration 10400: with minibatch training loss = 0.467 and accuracy of 0.92
# Iteration 10500: with minibatch training loss = 0.482 and accuracy of 0.92
# Iteration 10600: with minibatch training loss = 0.537 and accuracy of 0.88
# Iteration 10700: with minibatch training loss = 0.573 and accuracy of 0.89
# Epoch 14, Overall loss = 0.585 and accuracy of 0.898
# Iteration 10800: with minibatch training loss = 0.492 and accuracy of 0.94
# Iteration 10900: with minibatch training loss = 0.533 and accuracy of 0.91
# Iteration 11000: with minibatch training loss = 0.605 and accuracy of 0.86
# Iteration 11100: with minibatch training loss = 0.586 and accuracy of 0.91
# Iteration 11200: with minibatch training loss = 0.664 and accuracy of 0.88
# Iteration 11300: with minibatch training loss = 0.556 and accuracy of 0.94
# Iteration 11400: with minibatch training loss = 0.583 and accuracy of 0.89
# Epoch 15, Overall loss = 0.567 and accuracy of 0.907
# Iteration 11500: with minibatch training loss = 0.514 and accuracy of 0.89
# Iteration 11600: with minibatch training loss = 0.485 and accuracy of 0.94
# Iteration 11700: with minibatch training loss = 0.63 and accuracy of 0.83
# Iteration 11800: with minibatch training loss = 0.569 and accuracy of 0.88
# Iteration 11900: with minibatch training loss = 0.48 and accuracy of 0.94
# Iteration 12000: with minibatch training loss = 0.606 and accuracy of 0.92
# Iteration 12100: with minibatch training loss = 0.656 and accuracy of 0.88
# Iteration 12200: with minibatch training loss = 0.542 and accuracy of 0.95
# Epoch 16, Overall loss = 0.552 and accuracy of 0.911
# Iteration 12300: with minibatch training loss = 0.575 and accuracy of 0.89
# Iteration 12400: with minibatch training loss = 0.604 and accuracy of 0.89
# Iteration 12500: with minibatch training loss = 0.512 and accuracy of 0.92
# Iteration 12600: with minibatch training loss = 0.605 and accuracy of 0.86
# Iteration 12700: with minibatch training loss = 0.477 and accuracy of 0.97
# Iteration 12800: with minibatch training loss = 0.514 and accuracy of 0.95
# Iteration 12900: with minibatch training loss = 0.552 and accuracy of 0.92
# Iteration 13000: with minibatch training loss = 0.64 and accuracy of 0.86
# Epoch 17, Overall loss = 0.541 and accuracy of 0.913
# Iteration 13100: with minibatch training loss = 0.611 and accuracy of 0.89
# Iteration 13200: with minibatch training loss = 0.481 and accuracy of 0.94
# Iteration 13300: with minibatch training loss = 0.529 and accuracy of 0.91
# Iteration 13400: with minibatch training loss = 0.632 and accuracy of 0.89
# Iteration 13500: with minibatch training loss = 0.507 and accuracy of 0.97
# Iteration 13600: with minibatch training loss = 0.518 and accuracy of 0.88
# Iteration 13700: with minibatch training loss = 0.715 and accuracy of 0.86
# Epoch 18, Overall loss = 0.525 and accuracy of 0.919
# Iteration 13800: with minibatch training loss = 0.413 and accuracy of 0.97
# Iteration 13900: with minibatch training loss = 0.552 and accuracy of 0.89
# Iteration 14000: with minibatch training loss = 0.608 and accuracy of 0.88
# Iteration 14100: with minibatch training loss = 0.552 and accuracy of 0.92
# Iteration 14200: with minibatch training loss = 0.577 and accuracy of 0.88
# Iteration 14300: with minibatch training loss = 0.409 and accuracy of 0.98
# Iteration 14400: with minibatch training loss = 0.548 and accuracy of 0.89
# Iteration 14500: with minibatch training loss = 0.505 and accuracy of 0.92
# Epoch 19, Overall loss = 0.513 and accuracy of 0.925
# Iteration 14600: with minibatch training loss = 0.548 and accuracy of 0.92
# Iteration 14700: with minibatch training loss = 0.563 and accuracy of 0.89
# Iteration 14800: with minibatch training loss = 0.531 and accuracy of 0.92
# Iteration 14900: with minibatch training loss = 0.441 and accuracy of 0.98
# Iteration 15000: with minibatch training loss = 0.493 and accuracy of 0.97
# Iteration 15100: with minibatch training loss = 0.453 and accuracy of 0.94
# Iteration 15200: with minibatch training loss = 0.468 and accuracy of 0.95
# Iteration 15300: with minibatch training loss = 0.571 and accuracy of 0.86
# Epoch 20, Overall loss = 0.502 and accuracy of 0.927
# Iteration 15400: with minibatch training loss = 0.425 and accuracy of 0.97
# Iteration 15500: with minibatch training loss = 0.429 and accuracy of 0.95
# Iteration 15600: with minibatch training loss = 0.48 and accuracy of 0.92
# Iteration 15700: with minibatch training loss = 0.543 and accuracy of 0.91
# Iteration 15800: with minibatch training loss = 0.464 and accuracy of 0.92
# Iteration 15900: with minibatch training loss = 0.424 and accuracy of 0.94
# Iteration 16000: with minibatch training loss = 0.607 and accuracy of 0.89
# Epoch 21, Overall loss = 0.492 and accuracy of 0.928
# Iteration 16100: with minibatch training loss = 0.506 and accuracy of 0.89
# Iteration 16200: with minibatch training loss = 0.493 and accuracy of 0.91
# Iteration 16300: with minibatch training loss = 0.399 and accuracy of 0.98
# Iteration 16400: with minibatch training loss = 0.437 and accuracy of 0.92
# Iteration 16500: with minibatch training loss = 0.514 and accuracy of 0.91
# Iteration 16600: with minibatch training loss = 0.55 and accuracy of 0.88
# Iteration 16700: with minibatch training loss = 0.518 and accuracy of 0.91
# Iteration 16800: with minibatch training loss = 0.568 and accuracy of 0.84
# Epoch 22, Overall loss = 0.482 and accuracy of 0.931
# Iteration 16900: with minibatch training loss = 0.452 and accuracy of 0.95
# Iteration 17000: with minibatch training loss = 0.403 and accuracy of 0.98
# Iteration 17100: with minibatch training loss = 0.458 and accuracy of 0.94
# Iteration 17200: with minibatch training loss = 0.457 and accuracy of 0.94
# Iteration 17300: with minibatch training loss = 0.39 and accuracy of 0.97
# Iteration 17400: with minibatch training loss = 0.415 and accuracy of 0.97
# Iteration 17500: with minibatch training loss = 0.4 and accuracy of 0.97
# Iteration 17600: with minibatch training loss = 0.425 and accuracy of 0.97
# Epoch 23, Overall loss = 0.471 and accuracy of 0.934
# Iteration 17700: with minibatch training loss = 0.415 and accuracy of 0.97
# Iteration 17800: with minibatch training loss = 0.449 and accuracy of 0.92
# Iteration 17900: with minibatch training loss = 0.377 and accuracy of 0.98
# Iteration 18000: with minibatch training loss = 0.395 and accuracy of 0.98
# Iteration 18100: with minibatch training loss = 0.541 and accuracy of 0.91
# Iteration 18200: with minibatch training loss = 0.495 and accuracy of 0.92
# Iteration 18300: with minibatch training loss = 0.507 and accuracy of 0.89
# Epoch 24, Overall loss = 0.462 and accuracy of 0.936
# Iteration 18400: with minibatch training loss = 0.412 and accuracy of 0.94
# Iteration 18500: with minibatch training loss = 0.394 and accuracy of 0.98
# Iteration 18600: with minibatch training loss = 0.448 and accuracy of 0.94
# Iteration 18700: with minibatch training loss = 0.443 and accuracy of 0.92
# Iteration 18800: with minibatch training loss = 0.338 and accuracy of 1
# Iteration 18900: with minibatch training loss = 0.442 and accuracy of 0.94
# Iteration 19000: with minibatch training loss = 0.527 and accuracy of 0.89
# Iteration 19100: with minibatch training loss = 0.491 and accuracy of 0.94
# Epoch 25, Overall loss = 0.456 and accuracy of 0.938
# Iteration 19200: with minibatch training loss = 0.485 and accuracy of 0.91
# Iteration 19300: with minibatch training loss = 0.42 and accuracy of 0.97
# Iteration 19400: with minibatch training loss = 0.404 and accuracy of 0.97
# Iteration 19500: with minibatch training loss = 0.476 and accuracy of 0.92
# Iteration 19600: with minibatch training loss = 0.471 and accuracy of 0.97
# Iteration 19700: with minibatch training loss = 0.416 and accuracy of 0.94
# Iteration 19800: with minibatch training loss = 0.379 and accuracy of 0.98
# Iteration 19900: with minibatch training loss = 0.401 and accuracy of 0.95
# Epoch 26, Overall loss = 0.447 and accuracy of 0.94
# Iteration 20000: with minibatch training loss = 0.426 and accuracy of 0.95
# Iteration 20100: with minibatch training loss = 0.456 and accuracy of 0.94
# Iteration 20200: with minibatch training loss = 0.432 and accuracy of 0.94
# Iteration 20300: with minibatch training loss = 0.486 and accuracy of 0.91
# Iteration 20400: with minibatch training loss = 0.437 and accuracy of 0.92
# Iteration 20500: with minibatch training loss = 0.353 and accuracy of 0.97
# Iteration 20600: with minibatch training loss = 0.528 and accuracy of 0.89
# Epoch 27, Overall loss = 0.442 and accuracy of 0.939
# Iteration 20700: with minibatch training loss = 0.486 and accuracy of 0.91
# Iteration 20800: with minibatch training loss = 0.427 and accuracy of 0.91
# Iteration 20900: with minibatch training loss = 0.428 and accuracy of 0.98
# Iteration 21000: with minibatch training loss = 0.421 and accuracy of 0.95
# Iteration 21100: with minibatch training loss = 0.395 and accuracy of 0.97
# Iteration 21200: with minibatch training loss = 0.501 and accuracy of 0.89
# Iteration 21300: with minibatch training loss = 0.457 and accuracy of 0.95
# Iteration 21400: with minibatch training loss = 0.452 and accuracy of 0.94
# Epoch 28, Overall loss = 0.436 and accuracy of 0.94
# Iteration 21500: with minibatch training loss = 0.459 and accuracy of 0.91
# Iteration 21600: with minibatch training loss = 0.467 and accuracy of 0.91
# Iteration 21700: with minibatch training loss = 0.357 and accuracy of 1
# Iteration 21800: with minibatch training loss = 0.431 and accuracy of 0.94
# Iteration 21900: with minibatch training loss = 0.416 and accuracy of 0.94
# Iteration 22000: with minibatch training loss = 0.428 and accuracy of 0.94
# Iteration 22100: with minibatch training loss = 0.465 and accuracy of 0.94
# Iteration 22200: with minibatch training loss = 0.514 and accuracy of 0.86
# Epoch 29, Overall loss = 0.426 and accuracy of 0.942
# Iteration 22300: with minibatch training loss = 0.434 and accuracy of 0.92
# Iteration 22400: with minibatch training loss = 0.321 and accuracy of 0.98
# Iteration 22500: with minibatch training loss = 0.42 and accuracy of 0.91
# Iteration 22600: with minibatch training loss = 0.477 and accuracy of 0.91
# Iteration 22700: with minibatch training loss = 0.41 and accuracy of 0.95
# Iteration 22800: with minibatch training loss = 0.383 and accuracy of 0.95
# Iteration 22900: with minibatch training loss = 0.537 and accuracy of 0.88
# Epoch 30, Overall loss = 0.421 and accuracy of 0.943
# Iteration 23000: with minibatch training loss = 0.403 and accuracy of 0.94
# Iteration 23100: with minibatch training loss = 0.391 and accuracy of 0.97
# Iteration 23200: with minibatch training loss = 0.498 and accuracy of 0.91
# Iteration 23300: with minibatch training loss = 0.461 and accuracy of 0.94
# Iteration 23400: with minibatch training loss = 0.427 and accuracy of 0.94
# Iteration 23500: with minibatch training loss = 0.354 and accuracy of 0.98
# Iteration 23600: with minibatch training loss = 0.369 and accuracy of 0.98
# Iteration 23700: with minibatch training loss = 0.514 and accuracy of 0.92
# Epoch 31, Overall loss = 0.416 and accuracy of 0.945
# Iteration 23800: with minibatch training loss = 0.358 and accuracy of 0.95
# Iteration 23900: with minibatch training loss = 0.488 and accuracy of 0.91
# Iteration 24000: with minibatch training loss = 0.395 and accuracy of 0.92
# Iteration 24100: with minibatch training loss = 0.395 and accuracy of 0.97
# Iteration 24200: with minibatch training loss = 0.357 and accuracy of 0.98
# Iteration 24300: with minibatch training loss = 0.415 and accuracy of 0.94
# Iteration 24400: with minibatch training loss = 0.461 and accuracy of 0.94
# Iteration 24500: with minibatch training loss = 0.404 and accuracy of 0.95
# Epoch 32, Overall loss = 0.412 and accuracy of 0.946
# Iteration 24600: with minibatch training loss = 0.332 and accuracy of 0.98
# Iteration 24700: with minibatch training loss = 0.381 and accuracy of 0.97
# Iteration 24800: with minibatch training loss = 0.411 and accuracy of 0.94
# Iteration 24900: with minibatch training loss = 0.396 and accuracy of 0.97
# Iteration 25000: with minibatch training loss = 0.423 and accuracy of 0.94
# Iteration 25100: with minibatch training loss = 0.412 and accuracy of 0.95
# Iteration 25200: with minibatch training loss = 0.342 and accuracy of 0.98
# Epoch 33, Overall loss = 0.407 and accuracy of 0.946
# Iteration 25300: with minibatch training loss = 0.329 and accuracy of 1
# Iteration 25400: with minibatch training loss = 0.321 and accuracy of 0.98
# Iteration 25500: with minibatch training loss = 0.425 and accuracy of 0.91
# Iteration 25600: with minibatch training loss = 0.384 and accuracy of 0.95
# Iteration 25700: with minibatch training loss = 0.42 and accuracy of 0.95
# Iteration 25800: with minibatch training loss = 0.423 and accuracy of 0.95
# Iteration 25900: with minibatch training loss = 0.315 and accuracy of 0.98
# Iteration 26000: with minibatch training loss = 0.443 and accuracy of 0.95
# Epoch 34, Overall loss = 0.402 and accuracy of 0.947
# Iteration 26100: with minibatch training loss = 0.336 and accuracy of 0.97
# Iteration 26200: with minibatch training loss = 0.432 and accuracy of 0.94
# Iteration 26300: with minibatch training loss = 0.354 and accuracy of 0.97
# Iteration 26400: with minibatch training loss = 0.348 and accuracy of 0.97
# Iteration 26500: with minibatch training loss = 0.379 and accuracy of 0.94
# Iteration 26600: with minibatch training loss = 0.364 and accuracy of 0.97
# Iteration 26700: with minibatch training loss = 0.422 and accuracy of 0.94
# Iteration 26800: with minibatch training loss = 0.49 and accuracy of 0.91
# Epoch 35, Overall loss = 0.396 and accuracy of 0.948
# Iteration 26900: with minibatch training loss = 0.421 and accuracy of 0.94
# Iteration 27000: with minibatch training loss = 0.318 and accuracy of 1
# Iteration 27100: with minibatch training loss = 0.344 and accuracy of 0.94
# Iteration 27200: with minibatch training loss = 0.472 and accuracy of 0.92
# Iteration 27300: with minibatch training loss = 0.413 and accuracy of 0.95
# Iteration 27400: with minibatch training loss = 0.324 and accuracy of 0.97
# Iteration 27500: with minibatch training loss = 0.372 and accuracy of 0.97
# Epoch 36, Overall loss = 0.392 and accuracy of 0.948
# Iteration 27600: with minibatch training loss = 0.403 and accuracy of 0.94
# Iteration 27700: with minibatch training loss = 0.4 and accuracy of 0.92
# Iteration 27800: with minibatch training loss = 0.461 and accuracy of 0.92
# Iteration 27900: with minibatch training loss = 0.331 and accuracy of 0.97
# Iteration 28000: with minibatch training loss = 0.327 and accuracy of 0.98
# Iteration 28100: with minibatch training loss = 0.351 and accuracy of 0.98
# Iteration 28200: with minibatch training loss = 0.408 and accuracy of 0.95
# Iteration 28300: with minibatch training loss = 0.471 and accuracy of 0.92
# Epoch 37, Overall loss = 0.389 and accuracy of 0.95
# Iteration 28400: with minibatch training loss = 0.49 and accuracy of 0.89
# Iteration 28500: with minibatch training loss = 0.36 and accuracy of 0.97
# Iteration 28600: with minibatch training loss = 0.422 and accuracy of 0.92
# Iteration 28700: with minibatch training loss = 0.379 and accuracy of 0.94
# Iteration 28800: with minibatch training loss = 0.401 and accuracy of 0.91
# Iteration 28900: with minibatch training loss = 0.33 and accuracy of 0.97
# Iteration 29000: with minibatch training loss = 0.34 and accuracy of 0.95
# Iteration 29100: with minibatch training loss = 0.311 and accuracy of 0.97
# Epoch 38, Overall loss = 0.386 and accuracy of 0.949
# Iteration 29200: with minibatch training loss = 0.382 and accuracy of 0.95
# Iteration 29300: with minibatch training loss = 0.382 and accuracy of 0.95
# Iteration 29400: with minibatch training loss = 0.374 and accuracy of 0.97
# Iteration 29500: with minibatch training loss = 0.319 and accuracy of 1
# Iteration 29600: with minibatch training loss = 0.33 and accuracy of 0.97
# Iteration 29700: with minibatch training loss = 0.332 and accuracy of 0.98
# Iteration 29800: with minibatch training loss = 0.318 and accuracy of 1
# Epoch 39, Overall loss = 0.382 and accuracy of 0.95
# Iteration 29900: with minibatch training loss = 0.354 and accuracy of 0.97
# Iteration 30000: with minibatch training loss = 0.312 and accuracy of 1
# Iteration 30100: with minibatch training loss = 0.343 and accuracy of 0.94
# Iteration 30200: with minibatch training loss = 0.378 and accuracy of 0.95
# Iteration 30300: with minibatch training loss = 0.318 and accuracy of 1
# Iteration 30400: with minibatch training loss = 0.329 and accuracy of 0.98
# Iteration 30500: with minibatch training loss = 0.319 and accuracy of 0.97
# Iteration 30600: with minibatch training loss = 0.423 and accuracy of 0.92
# Epoch 40, Overall loss = 0.376 and accuracy of 0.951
# Iteration 30700: with minibatch training loss = 0.335 and accuracy of 0.97
# Iteration 30800: with minibatch training loss = 0.383 and accuracy of 0.95
# Iteration 30900: with minibatch training loss = 0.428 and accuracy of 0.91
# Iteration 31000: with minibatch training loss = 0.368 and accuracy of 0.98
# Iteration 31100: with minibatch training loss = 0.382 and accuracy of 0.95
# Iteration 31200: with minibatch training loss = 0.446 and accuracy of 0.92
# Iteration 31300: with minibatch training loss = 0.339 and accuracy of 0.95
# Iteration 31400: with minibatch training loss = 0.404 and accuracy of 0.92
# Epoch 41, Overall loss = 0.373 and accuracy of 0.953
# Iteration 31500: with minibatch training loss = 0.356 and accuracy of 0.95
# Iteration 31600: with minibatch training loss = 0.291 and accuracy of 1
# Iteration 31700: with minibatch training loss = 0.434 and accuracy of 0.91
# Iteration 31800: with minibatch training loss = 0.376 and accuracy of 0.95
# Iteration 31900: with minibatch training loss = 0.454 and accuracy of 0.94
# Iteration 32000: with minibatch training loss = 0.361 and accuracy of 0.95
# Iteration 32100: with minibatch training loss = 0.383 and accuracy of 0.97
# Epoch 42, Overall loss = 0.372 and accuracy of 0.952
# Iteration 32200: with minibatch training loss = 0.35 and accuracy of 0.95
# Iteration 32300: with minibatch training loss = 0.368 and accuracy of 0.92
# Iteration 32400: with minibatch training loss = 0.298 and accuracy of 0.98
# Iteration 32500: with minibatch training loss = 0.316 and accuracy of 1
# Iteration 32600: with minibatch training loss = 0.53 and accuracy of 0.89
# Iteration 32700: with minibatch training loss = 0.417 and accuracy of 0.95
# Iteration 32800: with minibatch training loss = 0.42 and accuracy of 0.91
# Iteration 32900: with minibatch training loss = 0.351 and accuracy of 0.97
# Epoch 43, Overall loss = 0.366 and accuracy of 0.953
# Iteration 33000: with minibatch training loss = 0.294 and accuracy of 1
# Iteration 33100: with minibatch training loss = 0.386 and accuracy of 0.92
# Iteration 33200: with minibatch training loss = 0.261 and accuracy of 1
# Iteration 33300: with minibatch training loss = 0.426 and accuracy of 0.94
# Iteration 33400: with minibatch training loss = 0.318 and accuracy of 0.97
# Iteration 33500: with minibatch training loss = 0.282 and accuracy of 1
# Iteration 33600: with minibatch training loss = 0.398 and accuracy of 0.91
# Iteration 33700: with minibatch training loss = 0.423 and accuracy of 0.91
# Epoch 44, Overall loss = 0.365 and accuracy of 0.954
# Iteration 33800: with minibatch training loss = 0.342 and accuracy of 0.95
# Iteration 33900: with minibatch training loss = 0.285 and accuracy of 0.98
# Iteration 34000: with minibatch training loss = 0.33 and accuracy of 0.98
# Iteration 34100: with minibatch training loss = 0.41 and accuracy of 0.91
# Iteration 34200: with minibatch training loss = 0.393 and accuracy of 0.95
# Iteration 34300: with minibatch training loss = 0.375 and accuracy of 0.97
# Iteration 34400: with minibatch training loss = 0.428 and accuracy of 0.92
# Epoch 45, Overall loss = 0.363 and accuracy of 0.954
# Iteration 34500: with minibatch training loss = 0.292 and accuracy of 1
# Iteration 34600: with minibatch training loss = 0.347 and accuracy of 0.95
# Iteration 34700: with minibatch training loss = 0.316 and accuracy of 0.97
# Iteration 34800: with minibatch training loss = 0.306 and accuracy of 0.98
# Iteration 34900: with minibatch training loss = 0.293 and accuracy of 1
# Iteration 35000: with minibatch training loss = 0.435 and accuracy of 0.95
# Iteration 35100: with minibatch training loss = 0.306 and accuracy of 0.94
# Iteration 35200: with minibatch training loss = 0.432 and accuracy of 0.91
# Epoch 46, Overall loss = 0.357 and accuracy of 0.954
# Iteration 35300: with minibatch training loss = 0.589 and accuracy of 0.92
# Iteration 35400: with minibatch training loss = 0.482 and accuracy of 0.89
# Iteration 35500: with minibatch training loss = 0.381 and accuracy of 0.97
# Iteration 35600: with minibatch training loss = 0.44 and accuracy of 0.92
# Iteration 35700: with minibatch training loss = 0.288 and accuracy of 0.98
# Iteration 35800: with minibatch training loss = 0.294 and accuracy of 0.97
# Iteration 35900: with minibatch training loss = 0.365 and accuracy of 0.94
# Iteration 36000: with minibatch training loss = 0.408 and accuracy of 0.92
# Epoch 47, Overall loss = 0.354 and accuracy of 0.955
# Iteration 36100: with minibatch training loss = 0.323 and accuracy of 0.95
# Iteration 36200: with minibatch training loss = 0.343 and accuracy of 0.97
# Iteration 36300: with minibatch training loss = 0.427 and accuracy of 0.91
# Iteration 36400: with minibatch training loss = 0.335 and accuracy of 0.97
# Iteration 36500: with minibatch training loss = 0.299 and accuracy of 1
# Iteration 36600: with minibatch training loss = 0.341 and accuracy of 0.94
# Iteration 36700: with minibatch training loss = 0.406 and accuracy of 0.92
# Epoch 48, Overall loss = 0.353 and accuracy of 0.955
# Iteration 36800: with minibatch training loss = 0.444 and accuracy of 0.91
# Iteration 36900: with minibatch training loss = 0.295 and accuracy of 1
# Iteration 37000: with minibatch training loss = 0.319 and accuracy of 0.97
# Iteration 37100: with minibatch training loss = 0.357 and accuracy of 0.92
# Iteration 37200: with minibatch training loss = 0.359 and accuracy of 0.95
# Iteration 37300: with minibatch training loss = 0.403 and accuracy of 0.94
# Iteration 37400: with minibatch training loss = 0.304 and accuracy of 0.97
# Iteration 37500: with minibatch training loss = 0.342 and accuracy of 0.95
# Epoch 49, Overall loss = 0.35 and accuracy of 0.956
# Iteration 37600: with minibatch training loss = 0.535 and accuracy of 0.88
# Iteration 37700: with minibatch training loss = 0.249 and accuracy of 1
# Iteration 37800: with minibatch training loss = 0.349 and accuracy of 0.97
# Iteration 37900: with minibatch training loss = 0.385 and accuracy of 0.94
# Iteration 38000: with minibatch training loss = 0.4 and accuracy of 0.92
# Iteration 38100: with minibatch training loss = 0.263 and accuracy of 1
# Iteration 38200: with minibatch training loss = 0.263 and accuracy of 1
# Epoch 50, Overall loss = 0.346 and accuracy of 0.956
# Iteration 38300: with minibatch training loss = 0.494 and accuracy of 0.92
# Iteration 38400: with minibatch training loss = 0.376 and accuracy of 0.91
# Iteration 38500: with minibatch training loss = 0.352 and accuracy of 0.95
# Iteration 38600: with minibatch training loss = 0.294 and accuracy of 0.97
# Iteration 38700: with minibatch training loss = 0.358 and accuracy of 0.92
# Iteration 38800: with minibatch training loss = 0.385 and accuracy of 0.92
# Iteration 38900: with minibatch training loss = 0.393 and accuracy of 0.92
# Iteration 39000: with minibatch training loss = 0.489 and accuracy of 0.91
# Epoch 51, Overall loss = 0.345 and accuracy of 0.957
# Iteration 39100: with minibatch training loss = 0.281 and accuracy of 0.98
# Iteration 39200: with minibatch training loss = 0.427 and accuracy of 0.94
# Iteration 39300: with minibatch training loss = 0.379 and accuracy of 0.94
# Iteration 39400: with minibatch training loss = 0.257 and accuracy of 0.98
# Iteration 39500: with minibatch training loss = 0.305 and accuracy of 0.98
# Iteration 39600: with minibatch training loss = 0.379 and accuracy of 0.94
# Iteration 39700: with minibatch training loss = 0.291 and accuracy of 0.97
# Iteration 39800: with minibatch training loss = 0.282 and accuracy of 0.98
# Epoch 52, Overall loss = 0.338 and accuracy of 0.958
# Iteration 39900: with minibatch training loss = 0.362 and accuracy of 0.92
# Iteration 40000: with minibatch training loss = 0.365 and accuracy of 0.94
# Iteration 40100: with minibatch training loss = 0.299 and accuracy of 0.97
# Iteration 40200: with minibatch training loss = 0.44 and accuracy of 0.91
# Iteration 40300: with minibatch training loss = 0.331 and accuracy of 0.94
# Iteration 40400: with minibatch training loss = 0.374 and accuracy of 0.94
# Iteration 40500: with minibatch training loss = 0.331 and accuracy of 0.98
# Epoch 53, Overall loss = 0.338 and accuracy of 0.957
# Iteration 40600: with minibatch training loss = 0.335 and accuracy of 0.92
# Iteration 40700: with minibatch training loss = 0.355 and accuracy of 0.95
# Iteration 40800: with minibatch training loss = 0.319 and accuracy of 0.97
# Iteration 40900: with minibatch training loss = 0.308 and accuracy of 0.97
# Iteration 41000: with minibatch training loss = 0.324 and accuracy of 0.95
# Iteration 41100: with minibatch training loss = 0.348 and accuracy of 0.95
# Iteration 41200: with minibatch training loss = 0.368 and accuracy of 0.92
# Iteration 41300: with minibatch training loss = 0.309 and accuracy of 0.97
# Epoch 54, Overall loss = 0.335 and accuracy of 0.958
# Iteration 41400: with minibatch training loss = 0.314 and accuracy of 0.94
# Iteration 41500: with minibatch training loss = 0.29 and accuracy of 0.98
# Iteration 41600: with minibatch training loss = 0.387 and accuracy of 0.94
# Iteration 41700: with minibatch training loss = 0.344 and accuracy of 0.94
# Iteration 41800: with minibatch training loss = 0.359 and accuracy of 0.97
# Iteration 41900: with minibatch training loss = 0.248 and accuracy of 1
# Iteration 42000: with minibatch training loss = 0.311 and accuracy of 0.97
# Iteration 42100: with minibatch training loss = 0.267 and accuracy of 0.98
# Epoch 55, Overall loss = 0.334 and accuracy of 0.958
# Iteration 42200: with minibatch training loss = 0.378 and accuracy of 0.94
# Iteration 42300: with minibatch training loss = 0.362 and accuracy of 0.97
# Iteration 42400: with minibatch training loss = 0.315 and accuracy of 0.98
# Iteration 42500: with minibatch training loss = 0.348 and accuracy of 0.94
# Iteration 42600: with minibatch training loss = 0.404 and accuracy of 0.89
# Iteration 42700: with minibatch training loss = 0.31 and accuracy of 0.98
# Iteration 42800: with minibatch training loss = 0.315 and accuracy of 0.97
# Epoch 56, Overall loss = 0.331 and accuracy of 0.96
# Iteration 42900: with minibatch training loss = 0.313 and accuracy of 0.97
# Iteration 43000: with minibatch training loss = 0.318 and accuracy of 0.94
# Iteration 43100: with minibatch training loss = 0.332 and accuracy of 0.97
# Iteration 43200: with minibatch training loss = 0.287 and accuracy of 0.97
# Iteration 43300: with minibatch training loss = 0.369 and accuracy of 0.94
# Iteration 43400: with minibatch training loss = 0.382 and accuracy of 0.94
# Iteration 43500: with minibatch training loss = 0.349 and accuracy of 0.94
# Iteration 43600: with minibatch training loss = 0.362 and accuracy of 0.92
# Epoch 57, Overall loss = 0.329 and accuracy of 0.959
# Iteration 43700: with minibatch training loss = 0.299 and accuracy of 0.95
# Iteration 43800: with minibatch training loss = 0.271 and accuracy of 0.98
# Iteration 43900: with minibatch training loss = 0.27 and accuracy of 0.97
# Iteration 44000: with minibatch training loss = 0.387 and accuracy of 0.97
# Iteration 44100: with minibatch training loss = 0.328 and accuracy of 0.97
# Iteration 44200: with minibatch training loss = 0.317 and accuracy of 0.95
# Iteration 44300: with minibatch training loss = 0.471 and accuracy of 0.95
# Iteration 44400: with minibatch training loss = 0.399 and accuracy of 0.94
# Epoch 58, Overall loss = 0.327 and accuracy of 0.959
# Iteration 44500: with minibatch training loss = 0.413 and accuracy of 0.91
# Iteration 44600: with minibatch training loss = 0.254 and accuracy of 0.98
# Iteration 44700: with minibatch training loss = 0.238 and accuracy of 1
# Iteration 44800: with minibatch training loss = 0.319 and accuracy of 0.95
# Iteration 44900: with minibatch training loss = 0.302 and accuracy of 0.98
# Iteration 45000: with minibatch training loss = 0.249 and accuracy of 1
# Iteration 45100: with minibatch training loss = 0.325 and accuracy of 0.97
# Epoch 59, Overall loss = 0.327 and accuracy of 0.959
# Iteration 45200: with minibatch training loss = 0.349 and accuracy of 0.97
# Iteration 45300: with minibatch training loss = 0.31 and accuracy of 0.97
# Iteration 45400: with minibatch training loss = 0.323 and accuracy of 0.97
# Iteration 45500: with minibatch training loss = 0.289 and accuracy of 0.97
# Iteration 45600: with minibatch training loss = 0.331 and accuracy of 0.95
# Iteration 45700: with minibatch training loss = 0.258 and accuracy of 0.97
# Iteration 45800: with minibatch training loss = 0.281 and accuracy of 0.97
# Iteration 45900: with minibatch training loss = 0.374 and accuracy of 0.95
# Epoch 60, Overall loss = 0.322 and accuracy of 0.96
# Iteration 46000: with minibatch training loss = 0.39 and accuracy of 0.91
# Iteration 46100: with minibatch training loss = 0.322 and accuracy of 0.97
# Iteration 46200: with minibatch training loss = 0.272 and accuracy of 0.97
# Iteration 46300: with minibatch training loss = 0.275 and accuracy of 0.98
# Iteration 46400: with minibatch training loss = 0.303 and accuracy of 0.97
# Iteration 46500: with minibatch training loss = 0.321 and accuracy of 0.95
# Iteration 46600: with minibatch training loss = 0.343 and accuracy of 0.95
# Iteration 46700: with minibatch training loss = 0.289 and accuracy of 0.98
# Epoch 61, Overall loss = 0.321 and accuracy of 0.96
# Iteration 46800: with minibatch training loss = 0.386 and accuracy of 0.94
# Iteration 46900: with minibatch training loss = 0.26 and accuracy of 0.97
# Iteration 47000: with minibatch training loss = 0.253 and accuracy of 1
# Iteration 47100: with minibatch training loss = 0.411 and accuracy of 0.92
# Iteration 47200: with minibatch training loss = 0.307 and accuracy of 0.95
# Iteration 47300: with minibatch training loss = 0.315 and accuracy of 0.95
# Iteration 47400: with minibatch training loss = 0.29 and accuracy of 0.97
# Epoch 62, Overall loss = 0.32 and accuracy of 0.961
# Iteration 47500: with minibatch training loss = 0.273 and accuracy of 0.98
# Iteration 47600: with minibatch training loss = 0.35 and accuracy of 0.98
# Iteration 47700: with minibatch training loss = 0.371 and accuracy of 0.94
# Iteration 47800: with minibatch training loss = 0.347 and accuracy of 0.98
# Iteration 47900: with minibatch training loss = 0.333 and accuracy of 0.94
# Iteration 48000: with minibatch training loss = 0.34 and accuracy of 0.97
# Iteration 48100: with minibatch training loss = 0.418 and accuracy of 0.95
# Iteration 48200: with minibatch training loss = 0.338 and accuracy of 0.95
# Epoch 63, Overall loss = 0.32 and accuracy of 0.962
# Iteration 48300: with minibatch training loss = 0.31 and accuracy of 0.98
# Iteration 48400: with minibatch training loss = 0.253 and accuracy of 1
# Iteration 48500: with minibatch training loss = 0.308 and accuracy of 0.95
# Iteration 48600: with minibatch training loss = 0.363 and accuracy of 0.94
# Iteration 48700: with minibatch training loss = 0.258 and accuracy of 0.97
# Iteration 48800: with minibatch training loss = 0.321 and accuracy of 0.97
# Iteration 48900: with minibatch training loss = 0.345 and accuracy of 0.95
# Iteration 49000: with minibatch training loss = 0.314 and accuracy of 0.95
# Epoch 64, Overall loss = 0.317 and accuracy of 0.961
# Iteration 49100: with minibatch training loss = 0.316 and accuracy of 0.94
# Iteration 49200: with minibatch training loss = 0.259 and accuracy of 0.98
# Iteration 49300: with minibatch training loss = 0.336 and accuracy of 0.95
# Iteration 49400: with minibatch training loss = 0.403 and accuracy of 0.94
# Iteration 49500: with minibatch training loss = 0.364 and accuracy of 0.91
# Iteration 49600: with minibatch training loss = 0.282 and accuracy of 0.98
# Iteration 49700: with minibatch training loss = 0.405 and accuracy of 0.94
# Epoch 65, Overall loss = 0.317 and accuracy of 0.961
# Iteration 49800: with minibatch training loss = 0.27 and accuracy of 0.98
# Iteration 49900: with minibatch training loss = 0.266 and accuracy of 0.98
# Iteration 50000: with minibatch training loss = 0.295 and accuracy of 0.98
# Iteration 50100: with minibatch training loss = 0.291 and accuracy of 0.97
# Iteration 50200: with minibatch training loss = 0.299 and accuracy of 0.95
# Iteration 50300: with minibatch training loss = 0.323 and accuracy of 0.97
# Iteration 50400: with minibatch training loss = 0.406 and accuracy of 0.89
# Iteration 50500: with minibatch training loss = 0.289 and accuracy of 0.97
# Epoch 66, Overall loss = 0.314 and accuracy of 0.962
# Iteration 50600: with minibatch training loss = 0.333 and accuracy of 0.97
# Iteration 50700: with minibatch training loss = 0.362 and accuracy of 0.95
# Iteration 50800: with minibatch training loss = 0.302 and accuracy of 0.95
# Iteration 50900: with minibatch training loss = 0.299 and accuracy of 0.98
# Iteration 51000: with minibatch training loss = 0.232 and accuracy of 1
# Iteration 51100: with minibatch training loss = 0.356 and accuracy of 0.94
# Iteration 51200: with minibatch training loss = 0.346 and accuracy of 0.95
# Iteration 51300: with minibatch training loss = 0.301 and accuracy of 0.94
# Epoch 67, Overall loss = 0.311 and accuracy of 0.962
# Iteration 51400: with minibatch training loss = 0.439 and accuracy of 0.91
# Iteration 51500: with minibatch training loss = 0.291 and accuracy of 0.97
# Iteration 51600: with minibatch training loss = 0.311 and accuracy of 0.95
# Iteration 51700: with minibatch training loss = 0.278 and accuracy of 0.98
# Iteration 51800: with minibatch training loss = 0.263 and accuracy of 0.97
# Iteration 51900: with minibatch training loss = 0.309 and accuracy of 0.97
# Iteration 52000: with minibatch training loss = 0.335 and accuracy of 0.95
# Epoch 68, Overall loss = 0.312 and accuracy of 0.962
# Iteration 52100: with minibatch training loss = 0.237 and accuracy of 1
# Iteration 52200: with minibatch training loss = 0.253 and accuracy of 0.98
# Iteration 52300: with minibatch training loss = 0.318 and accuracy of 0.97
# Iteration 52400: with minibatch training loss = 0.274 and accuracy of 1
# Iteration 52500: with minibatch training loss = 0.4 and accuracy of 0.95
# Iteration 52600: with minibatch training loss = 0.259 and accuracy of 0.98
# Iteration 52700: with minibatch training loss = 0.289 and accuracy of 0.95
# Iteration 52800: with minibatch training loss = 0.349 and accuracy of 0.92
# Epoch 69, Overall loss = 0.31 and accuracy of 0.962
# Iteration 52900: with minibatch training loss = 0.316 and accuracy of 0.95
# Iteration 53000: with minibatch training loss = 0.307 and accuracy of 0.97
# Iteration 53100: with minibatch training loss = 0.312 and accuracy of 0.95
# Iteration 53200: with minibatch training loss = 0.304 and accuracy of 0.98
# Iteration 53300: with minibatch training loss = 0.306 and accuracy of 0.95
# Iteration 53400: with minibatch training loss = 0.289 and accuracy of 0.97
# Iteration 53500: with minibatch training loss = 0.358 and accuracy of 0.94
# Iteration 53600: with minibatch training loss = 0.351 and accuracy of 0.91
# Epoch 70, Overall loss = 0.31 and accuracy of 0.963
# Iteration 53700: with minibatch training loss = 0.241 and accuracy of 1
# Iteration 53800: with minibatch training loss = 0.307 and accuracy of 0.94
# Iteration 53900: with minibatch training loss = 0.363 and accuracy of 0.94
# Iteration 54000: with minibatch training loss = 0.349 and accuracy of 0.92
# Iteration 54100: with minibatch training loss = 0.234 and accuracy of 1
# Iteration 54200: with minibatch training loss = 0.301 and accuracy of 0.95
# Iteration 54300: with minibatch training loss = 0.361 and accuracy of 0.95
# Epoch 71, Overall loss = 0.309 and accuracy of 0.961
# Iteration 54400: with minibatch training loss = 0.352 and accuracy of 0.95
# Iteration 54500: with minibatch training loss = 0.272 and accuracy of 0.97
# Iteration 54600: with minibatch training loss = 0.248 and accuracy of 0.98
# Iteration 54700: with minibatch training loss = 0.298 and accuracy of 0.95
# Iteration 54800: with minibatch training loss = 0.29 and accuracy of 0.97
# Iteration 54900: with minibatch training loss = 0.333 and accuracy of 0.95
# Iteration 55000: with minibatch training loss = 0.311 and accuracy of 0.95
# Iteration 55100: with minibatch training loss = 0.341 and accuracy of 0.95
# Epoch 72, Overall loss = 0.305 and accuracy of 0.964
# Iteration 55200: with minibatch training loss = 0.296 and accuracy of 0.97
# Iteration 55300: with minibatch training loss = 0.286 and accuracy of 0.97
# Iteration 55400: with minibatch training loss = 0.253 and accuracy of 0.97
# Iteration 55500: with minibatch training loss = 0.321 and accuracy of 0.94
# Iteration 55600: with minibatch training loss = 0.277 and accuracy of 0.95
# Iteration 55700: with minibatch training loss = 0.348 and accuracy of 0.95
# Iteration 55800: with minibatch training loss = 0.317 and accuracy of 0.97
# Iteration 55900: with minibatch training loss = 0.428 and accuracy of 0.91
# Epoch 73, Overall loss = 0.305 and accuracy of 0.963
# Iteration 56000: with minibatch training loss = 0.309 and accuracy of 0.95
# Iteration 56100: with minibatch training loss = 0.325 and accuracy of 0.95
# Iteration 56200: with minibatch training loss = 0.37 and accuracy of 0.94
# Iteration 56300: with minibatch training loss = 0.266 and accuracy of 0.97
# Iteration 56400: with minibatch training loss = 0.359 and accuracy of 0.95
# Iteration 56500: with minibatch training loss = 0.263 and accuracy of 0.98
# Iteration 56600: with minibatch training loss = 0.441 and accuracy of 0.92
# Epoch 74, Overall loss = 0.301 and accuracy of 0.965
# Iteration 56700: with minibatch training loss = 0.277 and accuracy of 0.97
# Iteration 56800: with minibatch training loss = 0.246 and accuracy of 0.98
# Iteration 56900: with minibatch training loss = 0.33 and accuracy of 0.95
# Iteration 57000: with minibatch training loss = 0.273 and accuracy of 1
# Iteration 57100: with minibatch training loss = 0.301 and accuracy of 0.97
# Iteration 57200: with minibatch training loss = 0.266 and accuracy of 0.98
# Iteration 57300: with minibatch training loss = 0.328 and accuracy of 0.95
# Iteration 57400: with minibatch training loss = 0.342 and accuracy of 0.94
# Epoch 75, Overall loss = 0.303 and accuracy of 0.963
# Iteration 57500: with minibatch training loss = 0.269 and accuracy of 0.98
# Iteration 57600: with minibatch training loss = 0.342 and accuracy of 0.97
# Iteration 57700: with minibatch training loss = 0.295 and accuracy of 0.98
# Iteration 57800: with minibatch training loss = 0.269 and accuracy of 0.97
# Iteration 57900: with minibatch training loss = 0.411 and accuracy of 0.94
# Iteration 58000: with minibatch training loss = 0.413 and accuracy of 0.89
# Iteration 58100: with minibatch training loss = 0.312 and accuracy of 0.95
# Iteration 58200: with minibatch training loss = 0.261 and accuracy of 0.98
# Epoch 76, Overall loss = 0.298 and accuracy of 0.965
# Iteration 58300: with minibatch training loss = 0.27 and accuracy of 0.98
# Iteration 58400: with minibatch training loss = 0.386 and accuracy of 0.89
# Iteration 58500: with minibatch training loss = 0.294 and accuracy of 0.95
# Iteration 58600: with minibatch training loss = 0.248 and accuracy of 0.98
# Iteration 58700: with minibatch training loss = 0.216 and accuracy of 1
# Iteration 58800: with minibatch training loss = 0.281 and accuracy of 0.97
# Iteration 58900: with minibatch training loss = 0.31 and accuracy of 0.94
# Epoch 77, Overall loss = 0.297 and accuracy of 0.964
# Iteration 59000: with minibatch training loss = 0.283 and accuracy of 0.95
# Iteration 59100: with minibatch training loss = 0.301 and accuracy of 0.95
# Iteration 59200: with minibatch training loss = 0.269 and accuracy of 0.97
# Iteration 59300: with minibatch training loss = 0.238 and accuracy of 1
# Iteration 59400: with minibatch training loss = 0.252 and accuracy of 0.98
# Iteration 59500: with minibatch training loss = 0.258 and accuracy of 0.98
# Iteration 59600: with minibatch training loss = 0.315 and accuracy of 0.95
# Iteration 59700: with minibatch training loss = 0.296 and accuracy of 0.95
# Epoch 78, Overall loss = 0.299 and accuracy of 0.964
# Iteration 59800: with minibatch training loss = 0.289 and accuracy of 0.97
# Iteration 59900: with minibatch training loss = 0.361 and accuracy of 0.97
# Iteration 60000: with minibatch training loss = 0.231 and accuracy of 0.98
# Iteration 60100: with minibatch training loss = 0.274 and accuracy of 0.97
# Iteration 60200: with minibatch training loss = 0.374 and accuracy of 0.92
# Iteration 60300: with minibatch training loss = 0.223 and accuracy of 0.98
# Iteration 60400: with minibatch training loss = 0.378 and accuracy of 0.95
# Iteration 60500: with minibatch training loss = 0.3 and accuracy of 0.94
# Epoch 79, Overall loss = 0.296 and accuracy of 0.963
# Iteration 60600: with minibatch training loss = 0.322 and accuracy of 0.97
# Iteration 60700: with minibatch training loss = 0.223 and accuracy of 0.98
# Iteration 60800: with minibatch training loss = 0.325 and accuracy of 0.94
# Iteration 60900: with minibatch training loss = 0.277 and accuracy of 0.97
# Iteration 61000: with minibatch training loss = 0.268 and accuracy of 0.97
# Iteration 61100: with minibatch training loss = 0.291 and accuracy of 0.94
# Iteration 61200: with minibatch training loss = 0.255 and accuracy of 0.95
# Epoch 80, Overall loss = 0.292 and accuracy of 0.965
# Iteration 61300: with minibatch training loss = 0.288 and accuracy of 0.97
# Iteration 61400: with minibatch training loss = 0.278 and accuracy of 0.98
# Iteration 61500: with minibatch training loss = 0.265 and accuracy of 0.98
# Iteration 61600: with minibatch training loss = 0.282 and accuracy of 0.95
# Iteration 61700: with minibatch training loss = 0.232 and accuracy of 1
# Iteration 61800: with minibatch training loss = 0.333 and accuracy of 0.92
# Iteration 61900: with minibatch training loss = 0.273 and accuracy of 0.97
# Iteration 62000: with minibatch training loss = 0.304 and accuracy of 0.97
# Epoch 81, Overall loss = 0.292 and accuracy of 0.964
# Iteration 62100: with minibatch training loss = 0.347 and accuracy of 0.97
# Iteration 62200: with minibatch training loss = 0.308 and accuracy of 0.94
# Iteration 62300: with minibatch training loss = 0.262 and accuracy of 0.97
# Iteration 62400: with minibatch training loss = 0.236 and accuracy of 0.98
# Iteration 62500: with minibatch training loss = 0.221 and accuracy of 1
# Iteration 62600: with minibatch training loss = 0.262 and accuracy of 0.95
# Iteration 62700: with minibatch training loss = 0.283 and accuracy of 0.95
# Iteration 62800: with minibatch training loss = 0.389 and accuracy of 0.95
# Epoch 82, Overall loss = 0.29 and accuracy of 0.965
# Iteration 62900: with minibatch training loss = 0.214 and accuracy of 1
# Iteration 63000: with minibatch training loss = 0.238 and accuracy of 0.98
# Iteration 63100: with minibatch training loss = 0.269 and accuracy of 0.97
# Iteration 63200: with minibatch training loss = 0.236 and accuracy of 0.98
# Iteration 63300: with minibatch training loss = 0.26 and accuracy of 0.97
# Iteration 63400: with minibatch training loss = 0.252 and accuracy of 0.97
# Iteration 63500: with minibatch training loss = 0.237 and accuracy of 1
# Epoch 83, Overall loss = 0.291 and accuracy of 0.965
# Iteration 63600: with minibatch training loss = 0.329 and accuracy of 0.94
# Iteration 63700: with minibatch training loss = 0.269 and accuracy of 0.98
# Iteration 63800: with minibatch training loss = 0.259 and accuracy of 0.97
# Iteration 63900: with minibatch training loss = 0.291 and accuracy of 0.97
# Iteration 64000: with minibatch training loss = 0.321 and accuracy of 0.95
# Iteration 64100: with minibatch training loss = 0.247 and accuracy of 0.97
# Iteration 64200: with minibatch training loss = 0.27 and accuracy of 0.95
# Iteration 64300: with minibatch training loss = 0.253 and accuracy of 0.97
# Epoch 84, Overall loss = 0.29 and accuracy of 0.965
# Iteration 64400: with minibatch training loss = 0.265 and accuracy of 0.97
# Iteration 64500: with minibatch training loss = 0.37 and accuracy of 0.95
# Iteration 64600: with minibatch training loss = 0.325 and accuracy of 0.95
# Iteration 64700: with minibatch training loss = 0.315 and accuracy of 0.97
# Iteration 64800: with minibatch training loss = 0.228 and accuracy of 0.98
# Iteration 64900: with minibatch training loss = 0.315 and accuracy of 0.95
# Iteration 65000: with minibatch training loss = 0.313 and accuracy of 0.94
# Iteration 65100: with minibatch training loss = 0.308 and accuracy of 0.98
# Epoch 85, Overall loss = 0.287 and accuracy of 0.966
# Iteration 65200: with minibatch training loss = 0.259 and accuracy of 0.97
# Iteration 65300: with minibatch training loss = 0.336 and accuracy of 0.94
# Iteration 65400: with minibatch training loss = 0.272 and accuracy of 0.97
# Iteration 65500: with minibatch training loss = 0.275 and accuracy of 0.97
# Iteration 65600: with minibatch training loss = 0.317 and accuracy of 0.95
# Iteration 65700: with minibatch training loss = 0.25 and accuracy of 0.98
# Iteration 65800: with minibatch training loss = 0.348 and accuracy of 0.89
# Epoch 86, Overall loss = 0.291 and accuracy of 0.964
# Iteration 65900: with minibatch training loss = 0.275 and accuracy of 0.97
# Iteration 66000: with minibatch training loss = 0.223 and accuracy of 0.98
# Iteration 66100: with minibatch training loss = 0.262 and accuracy of 0.97
# Iteration 66200: with minibatch training loss = 0.313 and accuracy of 0.97
# Iteration 66300: with minibatch training loss = 0.23 and accuracy of 1
# Iteration 66400: with minibatch training loss = 0.245 and accuracy of 0.98
# Iteration 66500: with minibatch training loss = 0.249 and accuracy of 0.97
# Iteration 66600: with minibatch training loss = 0.319 and accuracy of 0.95
# Epoch 87, Overall loss = 0.285 and accuracy of 0.967
# Iteration 66700: with minibatch training loss = 0.304 and accuracy of 0.95
# Iteration 66800: with minibatch training loss = 0.262 and accuracy of 0.98
# Iteration 66900: with minibatch training loss = 0.29 and accuracy of 0.97
# Iteration 67000: with minibatch training loss = 0.307 and accuracy of 0.94
# Iteration 67100: with minibatch training loss = 0.24 and accuracy of 0.98
# Iteration 67200: with minibatch training loss = 0.267 and accuracy of 0.97
# Iteration 67300: with minibatch training loss = 0.281 and accuracy of 0.97
# Iteration 67400: with minibatch training loss = 0.227 and accuracy of 1
# Epoch 88, Overall loss = 0.284 and accuracy of 0.965
# Iteration 67500: with minibatch training loss = 0.212 and accuracy of 1
# Iteration 67600: with minibatch training loss = 0.369 and accuracy of 0.94
# Iteration 67700: with minibatch training loss = 0.201 and accuracy of 1
# Iteration 67800: with minibatch training loss = 0.237 and accuracy of 0.98
# Iteration 67900: with minibatch training loss = 0.281 and accuracy of 0.97
# Iteration 68000: with minibatch training loss = 0.311 and accuracy of 0.95
# Iteration 68100: with minibatch training loss = 0.232 and accuracy of 0.98
# Epoch 89, Overall loss = 0.282 and accuracy of 0.967
# Iteration 68200: with minibatch training loss = 0.217 and accuracy of 1
# Iteration 68300: with minibatch training loss = 0.312 and accuracy of 0.98
# Iteration 68400: with minibatch training loss = 0.317 and accuracy of 0.97
# Iteration 68500: with minibatch training loss = 0.25 and accuracy of 0.97
# Iteration 68600: with minibatch training loss = 0.346 and accuracy of 0.95
# Iteration 68700: with minibatch training loss = 0.375 and accuracy of 0.95
# Iteration 68800: with minibatch training loss = 0.315 and accuracy of 0.95
# Iteration 68900: with minibatch training loss = 0.23 and accuracy of 0.98
# Epoch 90, Overall loss = 0.285 and accuracy of 0.966
# Iteration 69000: with minibatch training loss = 0.239 and accuracy of 0.98
# Iteration 69100: with minibatch training loss = 0.245 and accuracy of 0.97
# Iteration 69200: with minibatch training loss = 0.288 and accuracy of 0.95
# Iteration 69300: with minibatch training loss = 0.255 and accuracy of 0.97
# Iteration 69400: with minibatch training loss = 0.231 and accuracy of 0.98
# Iteration 69500: with minibatch training loss = 0.352 and accuracy of 0.94
# Iteration 69600: with minibatch training loss = 0.323 and accuracy of 0.95
# Iteration 69700: with minibatch training loss = 0.264 and accuracy of 0.98
# Epoch 91, Overall loss = 0.283 and accuracy of 0.966
# Iteration 69800: with minibatch training loss = 0.265 and accuracy of 0.95
# Iteration 69900: with minibatch training loss = 0.272 and accuracy of 0.97
# Iteration 70000: with minibatch training loss = 0.262 and accuracy of 0.98
# Iteration 70100: with minibatch training loss = 0.263 and accuracy of 0.97
# Iteration 70200: with minibatch training loss = 0.295 and accuracy of 0.95
# Iteration 70300: with minibatch training loss = 0.245 and accuracy of 0.98
# Iteration 70400: with minibatch training loss = 0.291 and accuracy of 0.97
# Epoch 92, Overall loss = 0.278 and accuracy of 0.968
# Iteration 70500: with minibatch training loss = 0.253 and accuracy of 1
# Iteration 70600: with minibatch training loss = 0.228 and accuracy of 1
# Iteration 70700: with minibatch training loss = 0.276 and accuracy of 0.95
# Iteration 70800: with minibatch training loss = 0.291 and accuracy of 0.95
# Iteration 70900: with minibatch training loss = 0.401 and accuracy of 0.95
# Iteration 71000: with minibatch training loss = 0.345 and accuracy of 0.94
# Iteration 71100: with minibatch training loss = 0.227 and accuracy of 1
# Iteration 71200: with minibatch training loss = 0.25 and accuracy of 0.97
# Epoch 93, Overall loss = 0.279 and accuracy of 0.967
# Iteration 71300: with minibatch training loss = 0.222 and accuracy of 1
# Iteration 71400: with minibatch training loss = 0.258 and accuracy of 0.98
# Iteration 71500: with minibatch training loss = 0.29 and accuracy of 0.95
# Iteration 71600: with minibatch training loss = 0.317 and accuracy of 0.95
# Iteration 71700: with minibatch training loss = 0.224 and accuracy of 0.98
# Iteration 71800: with minibatch training loss = 0.34 and accuracy of 0.95
# Iteration 71900: with minibatch training loss = 0.234 and accuracy of 0.97
# Iteration 72000: with minibatch training loss = 0.273 and accuracy of 0.95
# Epoch 94, Overall loss = 0.279 and accuracy of 0.966
# Iteration 72100: with minibatch training loss = 0.212 and accuracy of 0.98
# Iteration 72200: with minibatch training loss = 0.321 and accuracy of 0.95
# Iteration 72300: with minibatch training loss = 0.312 and accuracy of 0.95
# Iteration 72400: with minibatch training loss = 0.297 and accuracy of 0.95
# Iteration 72500: with minibatch training loss = 0.272 and accuracy of 0.94
# Iteration 72600: with minibatch training loss = 0.346 and accuracy of 0.95
# Iteration 72700: with minibatch training loss = 0.269 and accuracy of 0.98
# Epoch 95, Overall loss = 0.278 and accuracy of 0.967
# Iteration 72800: with minibatch training loss = 0.197 and accuracy of 1
# Iteration 72900: with minibatch training loss = 0.25 and accuracy of 0.98
# Iteration 73000: with minibatch training loss = 0.228 and accuracy of 0.98
# Iteration 73100: with minibatch training loss = 0.277 and accuracy of 0.95
# Iteration 73200: with minibatch training loss = 0.324 and accuracy of 0.97
# Iteration 73300: with minibatch training loss = 0.232 and accuracy of 1
# Iteration 73400: with minibatch training loss = 0.19 and accuracy of 1
# Iteration 73500: with minibatch training loss = 0.291 and accuracy of 0.95
# Epoch 96, Overall loss = 0.276 and accuracy of 0.967
# Iteration 73600: with minibatch training loss = 0.333 and accuracy of 0.95
# Iteration 73700: with minibatch training loss = 0.23 and accuracy of 0.98
# Iteration 73800: with minibatch training loss = 0.253 and accuracy of 0.97
# Iteration 73900: with minibatch training loss = 0.244 and accuracy of 0.97
# Iteration 74000: with minibatch training loss = 0.252 and accuracy of 0.97
# Iteration 74100: with minibatch training loss = 0.222 and accuracy of 1
# Iteration 74200: with minibatch training loss = 0.265 and accuracy of 1
# Iteration 74300: with minibatch training loss = 0.406 and accuracy of 0.91
# Epoch 97, Overall loss = 0.274 and accuracy of 0.967
# Iteration 74400: with minibatch training loss = 0.348 and accuracy of 0.94
# Iteration 74500: with minibatch training loss = 0.208 and accuracy of 1
# Iteration 74600: with minibatch training loss = 0.29 and accuracy of 0.95
# Iteration 74700: with minibatch training loss = 0.25 and accuracy of 0.97
# Iteration 74800: with minibatch training loss = 0.232 and accuracy of 1
# Iteration 74900: with minibatch training loss = 0.262 and accuracy of 0.98
# Iteration 75000: with minibatch training loss = 0.265 and accuracy of 0.97
# Epoch 98, Overall loss = 0.275 and accuracy of 0.967
# Iteration 75100: with minibatch training loss = 0.344 and accuracy of 0.97
# Iteration 75200: with minibatch training loss = 0.268 and accuracy of 0.95
# Iteration 75300: with minibatch training loss = 0.261 and accuracy of 0.98
# Iteration 75400: with minibatch training loss = 0.223 and accuracy of 1
# Iteration 75500: with minibatch training loss = 0.263 and accuracy of 0.97
# Iteration 75600: with minibatch training loss = 0.299 and accuracy of 0.95
# Iteration 75700: with minibatch training loss = 0.273 and accuracy of 0.97
# Iteration 75800: with minibatch training loss = 0.198 and accuracy of 1
# Epoch 99, Overall loss = 0.272 and accuracy of 0.968
# Iteration 75900: with minibatch training loss = 0.348 and accuracy of 0.94
# Iteration 76000: with minibatch training loss = 0.243 and accuracy of 0.97
# Iteration 76100: with minibatch training loss = 0.23 and accuracy of 0.98
# Iteration 76200: with minibatch training loss = 0.23 and accuracy of 0.98
# Iteration 76300: with minibatch training loss = 0.315 and accuracy of 0.97
# Iteration 76400: with minibatch training loss = 0.206 and accuracy of 1
# Iteration 76500: with minibatch training loss = 0.262 and accuracy of 0.98
# Epoch 100, Overall loss = 0.272 and accuracy of 0.968
# Validation
# Epoch 1, Overall loss = 1.62 and accuracy of 0.723
# (1.6242299041748047, 0.72299999999999998)

# %%
# Test your model here, and make sure 
# the output of this cell is the accuracy
# of your best model on the training and val sets
# We're looking for >= 70% accuracy on Validation
print('Training')
run_model(sess,y_out['y_out'],mean_loss,X_train,y_train,1,64)
print('Validation')
run_model(sess,y_out['y_out'],mean_loss,X_val,y_val,1,64)
# Out:
# Training
# Epoch 1, Overall loss = 0.318 and accuracy of 0.95
# Validation
# Epoch 1, Overall loss = 1.65 and accuracy of 0.716
# (1.6545398445129396, 0.71599999999999997)

# %% [markdown]
# ### Describe what you did here
# In this cell you should also write an explanation of what you did, any additional features that you implemented, and any visualizations or graphs that you make in the process of training and evaluating your network

# %% [markdown]
# _Tell us here_

# %% [markdown]
# ### Test Set - Do this only once
# Now that we've gotten a result that we're happy with, we test our final model on the test set. This would be the score we would achieve on a competition. Think about how this compares to your validation set accuracy.

# %%
print('Test')
run_model(sess,y_out['y_out'],mean_loss,X_test,y_test,1,64)
# Out:
# Test
# Epoch 1, Overall loss = 1.71 and accuracy of 0.712
# (1.7135244873046875, 0.71189999999999998)

# %% [markdown]
# ## Going further with TensorFlow
#
# The next assignment will make heavy use of TensorFlow. You might also find it useful for your projects.

# %% [markdown]
# # Extra Credit Description
# If you implement any additional features for extra credit, clearly describe them here with pointers to any code in this or other files if applicable.
